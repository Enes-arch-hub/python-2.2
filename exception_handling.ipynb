# %%
laptops=15
students=3
share=int(laptops/students)
print(share)
print("Hello world")
# Out:
# 5
# Hello world

# %%
laptops=4
students=7
try:
    if laptops>=students:
        share=int(laptops/students)
    else:
        print("laptops are less")
    print(share)
    share=int(laptops/students)
except ZeroDivisionError:
    print("Error:Zero Students:")
except Exception as e:
    print("Error:",e)
    
    print("Hello World")
# Out:
# 5

# %%
laptops=5
students=7
try:
    assert laptops>=students,"laptops are less"
    share=int(laptops/students)
    print(share)
except Exception as e:
    print("Error:",e)
    
    print("Hello World")
# Out:
# Error: laptops are less
# Hello World

# %%
def safedivtwo(a,b):
    try:
        answer=int(a/b)
        remainder=a%b
        return(answer,remainder)
    except Exception as arg:
        print(arg)
    else:
        return(answer,remainder)
print(safedivtwo(13,0))
# Out:
# division by zero
# None

# %%
while True:
    try:
        num=int(input("Enter a number"))
        if num==0 or num>100:
            continue
        else:
            break
    except Exception as x:
        print(x)
        break
    else:
        print("completed successfully!")
