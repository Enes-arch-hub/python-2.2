# %%
class lecturer:
    'An examples of a class definition'
    lectCount=0
    def _init_(self, f,p,e):
        self.pfno=34
        self.phone='0112073904'
        self.email="enes@gmail.com"
    def teach(self):
        print(self,"enes@gmail.com","is teaching")
        
m=lecturer(34, '0112073904',"enes@gmail.com") 
m.teach()
