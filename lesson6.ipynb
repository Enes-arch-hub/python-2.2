# %%
#functions
def calcV(r,h):
    'this is a simple function'
    vol=3.142*r*r*h
    r=r*6
    print(vol)
    return 
x=7
y=10
calcV(x,y)
print(y)
# Out:
# 1539.58
# 10

# %%
def calcA(l,w=20):
    print("Length=",l,"Width=",w,"Area=",l*w)
    return
x=7
y=10
calcA(x)
# Out:
# Length= 7 Width= 20 Area= 140
